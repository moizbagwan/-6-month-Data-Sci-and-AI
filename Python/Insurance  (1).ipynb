# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv(r"C:\Users\hp\Downloads\insurance.csv")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
# Check the first few rows
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Check the last few rows
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
# Check general info: columns, data types, non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# Summary statistics for numeric columns
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Check for missing values
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Check column names
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
# List of numeric columns to visualize
numeric_columns = ['age', 'bmi', 'children', 'charges']

# Loop through each numeric column
for col in numeric_columns:
    # Create a new figure for each plot with size 6x4 inches
    plt.figure(figsize=(6,4))
    
    # Plot a histogram with KDE (smooth curve) and 20 bins
    # color='skyblue' gives a nice blue color to the bars
    sns.histplot(df[col], kde=True, bins=20, color='skyblue')
    
    # Add a title to the plot
    plt.title(f'Distribution of {col}', fontsize=14)
    
    # Label the x-axis with the column name
    plt.xlabel(col, fontsize=12)
    
    # Label the y-axis as 'Count'
    plt.ylabel('Count', fontsize=12)
    
    # Show the plot
    plt.show()

# %%
# Create a figure of size 6x4 inches
plt.figure(figsize=(6,4))

# Plot a countplot for the 'children' column
sns.countplot(x=df['children'], color='skyblue')

# Add title and axis labels
plt.title('Count of Children', fontsize=14)
plt.xlabel('Number of Children', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Show the plot
plt.show()

# %%
# Create a figure of size 6x4 inches
plt.figure(figsize=(6,4))

# Plot a countplot for the 'sex' column
sns.countplot(x=df['sex'], palette='pastel')  # 'palette' gives nice colors

# Add title and axis labels
plt.title('Count of Gender', fontsize=14)
plt.xlabel('Sex', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Show the plot
plt.show()

# %%
# Create a figure of size 6x4 inches
plt.figure(figsize=(6,4))

# Plot a countplot for the 'smoker' column
sns.countplot(x=df['smoker'], palette='Set2')  # 'Set2' gives nice distinct colors

# Add title and axis labels
plt.title('Count of Smoker Status', fontsize=14)
plt.xlabel('Smoker', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Show the plot
plt.show()

# %%
# Create a figure of size 6x4 inches
plt.figure(figsize=(6,4))

# Plot a countplot for the 'region' column
sns.countplot(x=df['region'], palette='Set3')  # 'Set3' gives distinct colors for categories

# Add title and axis labels
plt.title('Count of Region', fontsize=14)
plt.xlabel('Region', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Show the plot
plt.show()

# %%
# List of numeric columns
numeric_columns = ['age', 'bmi', 'children', 'charges']

# Loop through each numeric column
for col in numeric_columns:
    # Create a new figure for each boxplot
    plt.figure(figsize=(6,4))
    
    # Plot a boxplot for the current column
    sns.boxplot(x=df[col], color='lightgreen')
    
    # Add a title
    plt.title(f'Boxplot of {col}', fontsize=14)
    
    # Label the x-axis
    plt.xlabel(col, fontsize=12)
    
    # Show the plot
    plt.show()

# %%
# Create a figure of size 8x6 inches
plt.figure(figsize=(8,6))

# Compute correlation for numeric columns and plot a heatmap
sns.heatmap(df.corr(numeric_only=True),        # Correlation matrix of numeric columns
            annot=True,                        # Show correlation values on the heatmap
            cmap='coolwarm',                   # Color map for better visualization
            linewidths=0.5)                    # Lines between cells

# Add a title
plt.title('Correlation Heatmap of Numeric Features', fontsize=14)

# Show the plot
plt.show()

# %%
# Calculate percentage distribution of smoker categories
pie_data = df['smoker'].value_counts(normalize=True) * 100
labels = pie_data.index  # Category labels

# Create a figure of size 6x4 inches
plt.figure(figsize=(6,4))

# Plot a pie chart
plt.pie(pie_data, 
        labels=labels,         # Add category labels
        autopct='%.1f%%',      # Show percentages with 1 decimal place
        startangle=90)         # Rotate chart to start from top

# Add a white circle at the center to make it a donut chart
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()              # Get the current figure
fig.gca().add_artist(centre_circle)

# Add title
plt.title("Distribution of Smokers")

# Show the plot
plt.show()

# %% [markdown]
# # Data Cleaning & Prepocessing

# %%
clean_data = df.copy()

# %%
clean_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
clean_data.shape
# Out:
# (1338, 7)

# %%
clean_data.drop_duplicates(inplace=True)

# %%
clean_data.shape
# Out:
# (1337, 7)

# %%
clean_data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
clean_data = pd.get_dummies(clean_data,dtype=int)
clean_data
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# ...

# %%
clean_data['bmi_category'] = pd.cut(
    clean_data['bmi'],
    bins = [0, 18.5, 24.9, 29.9, float('inf')],
    labels = ['Under_weight', 'Normal', 'Over_weight','Obese']
)

clean_data
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# ...

# %%
clean_data = pd.get_dummies(clean_data,dtype=int)
clean_data
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# ...

# %%
# Import StandardScaler from scikit-learn
from sklearn.preprocessing import StandardScaler

cols = ['age', 'bmi', 'children']
scaler = StandardScaler()
clean_data[cols] = scaler.fit_transform(clean_data[cols])

clean_data
# Out:
#            age       bmi  children      charges  sex_female  sex_male  \
# 0    -1.440418 -0.453160 -0.909234  16884.92400           1         0
# 1    -1.511647  0.509422 -0.079442   1725.55230           0         1
# 2    -0.799350  0.383155  1.580143   4449.46200           0         1
# 3    -0.443201 -1.305052 -0.909234  21984.47061           0         1
# 4    -0.514431 -0.292456 -0.909234   3866.85520           0         1
# ...        ...       ...       ...          ...         ...       ...
# 1333  0.767704  0.050269  1.580143  10600.54830           0         1
# 1334 -1.511647  0.206053 -0.909234   2205.98080           1         0
# 1335 -1.511647  1.014490 -0.909234   1629.83350           1         0
# 1336 -1.297958 -0.797524 -0.909234   2007.94500           1         0
# 1337  1.551231 -0.261299 -0.909234  29141.36030           1         0
#
#       smoker_no  smoker_yes  region_northeast  region_northwest  \
# ...

# %%
# Display column names as a list
clean_data.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male',
#        'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest',
#        'region_southeast', 'region_southwest', 'bmi_category_Under_weight',
#        'bmi_category_Normal', 'bmi_category_Over_weight',
#        'bmi_category_Obese'],
#       dtype='object')

# %%
from scipy.stats import pearsonr
import pandas as pd

# List of features to check against target
selected_features = [
    'age', 'bmi', 'children', 'sex_female',
    'smoker_no', 'smoker_yes',
    'region_northwest', 'region_southeast', 'region_southwest',
    'bmi_category_Normal', 'bmi_category_Overweight', 'bmi_category_Obese'
]

# Calculate Pearson correlations
correlations = {
    feature: pearsonr(clean_data[feature], clean_data['charges'])[0]
    for feature in selected_features if feature in clean_data.columns
}

correlation_df = pd.DataFrame(list(correlations.items()), columns=['Feature', 'Pearson Correlation'])
correlation_df.sort_values(by='Pearson Correlation', ascending=False)
# Out:
#                 Feature  Pearson Correlation
# 5            smoker_yes             0.787234
# 0                   age             0.298308
# 1                   bmi             0.198401
# 10   bmi_category_Obese             0.197659
# 7      region_southeast             0.073578
# 2              children             0.067389
# 6      region_northwest            -0.038695
# 8      region_southwest            -0.043637
# 3            sex_female            -0.058044
# 9   bmi_category_Normal            -0.105655
# 4             smoker_no            -0.787234

# %%
print(clean_data.columns.tolist())
# Out:
# ['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest', 'bmi_category_Under_weight', 'bmi_category_Normal', 'bmi_category_Over_weight', 'bmi_category_Obese']

# %%
cat_features = [
    'sex_female', 'smoker_no',
    'region_northwest', 'region_southeast', 'region_southwest',
    'bmi_category_Normal', 'bmi_category_Overweight', 'bmi_category_Obese'
]

# %%
clean_data.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male',
#        'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest',
#        'region_southeast', 'region_southwest', 'bmi_category_Under_weight',
#        'bmi_category_Normal', 'bmi_category_Over_weight', 'bmi_category_Obese',
#        'charges_bin_Low', 'charges_bin_Medium', 'charges_bin_High',
#        'bmi_category_Under_weight', 'bmi_category_Normal',
#        'bmi_category_Over_weight', 'bmi_category_Obese', 'charges_bin'],
#       dtype='object')

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Example: binning 'charges' into 3 categories
# You can change bins as needed
clean_data['charges_bin'] = pd.qcut(clean_data['charges'], q=3, labels=['Low', 'Medium', 'High'])

alpha = 0.05
chi2_results = {}

for col in cat_features:
    if col in clean_data.columns:  
        contingency = pd.crosstab(clean_data[col], clean_data['charges_bin'])
        chi2_stat, p_val, _, _ = chi2_contingency(contingency)
        decision = 'Reject Null (Keep Feature)' if p_val < alpha else 'Accept Null (Drop Feature)'
        chi2_results[col] = {
            'chi2_statistic': chi2_stat,
            'p_value': p_val,
            'Decision': decision
        }

chi2_df = pd.DataFrame(chi2_results).T
chi2_df = chi2_df.sort_values(by='p_value')
chi2_df
# Out:
#                     chi2_statistic   p_value                    Decision
# smoker_no               688.480352       0.0  Reject Null (Keep Feature)
# region_southeast          7.809607  0.020145  Reject Null (Keep Feature)
# region_southwest           5.78464  0.055447  Accept Null (Drop Feature)
# bmi_category_Obese         4.06967  0.130702  Accept Null (Drop Feature)
# bmi_category_Normal       3.602684  0.165077  Accept Null (Drop Feature)
# sex_female                2.074801  0.354375  Accept Null (Drop Feature)
# region_northwest          1.575696  0.454822  Accept Null (Drop Feature)

# %%
clean_data.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male',
#        'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest',
#        'region_southeast', 'region_southwest', 'bmi_category_Under_weight',
#        'bmi_category_Normal', 'bmi_category_Over_weight', 'bmi_category_Obese',
#        'charges_bin'],
#       dtype='object')

# %%
final_df = clean_data[['age', 'sex_female', 'bmi', 'children', 'smoker_yes', 'charges','region_southeast', 'bmi_category_Obese']]

# %%
final_df
# Out:
#            age  sex_female       bmi  children  smoker_yes      charges  \
# 0    -1.440418           1 -0.453160 -0.909234           1  16884.92400
# 1    -1.511647           0  0.509422 -0.079442           0   1725.55230
# 2    -0.799350           0  0.383155  1.580143           0   4449.46200
# 3    -0.443201           0 -1.305052 -0.909234           0  21984.47061
# 4    -0.514431           0 -0.292456 -0.909234           0   3866.85520
# ...        ...         ...       ...       ...         ...          ...
# 1333  0.767704           0  0.050269  1.580143           0  10600.54830
# 1334 -1.511647           1  0.206053 -0.909234           0   2205.98080
# 1335 -1.511647           1  1.014490 -0.909234           0   1629.83350
# 1336 -1.297958           1 -0.797524 -0.909234           0   2007.94500
# 1337  1.551231           1 -0.261299 -0.909234           1  29141.36030
#
#       region_southeast  bmi_category_Obese
# 0                    0                   0
# ...

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
clean_data.describe()
# Out:
#                 age           bmi      children       charges   sex_female  \
# count  1.337000e+03  1.337000e+03  1.337000e+03   1337.000000  1337.000000
# mean  -6.643070e-17 -2.285216e-16  3.852980e-17  13279.121487     0.495138
# std    1.000374e+00  1.000374e+00  1.000374e+00  12110.359656     0.500163
# min   -1.511647e+00 -2.411119e+00 -9.092342e-01   1121.873900     0.000000
# 25%   -8.705798e-01 -7.171725e-01 -9.092342e-01   4746.344000     0.000000
# 50%   -1.582291e-02 -4.320166e-02 -7.944162e-02   9386.161300     0.000000
# 75%    8.389340e-01  6.619260e-01  7.503509e-01  16657.717450     1.000000
# max    1.764921e+00  3.684136e+00  3.239729e+00  63770.428010     1.000000
#
#           sex_male    smoker_no   smoker_yes  region_northeast  \
# count  1337.000000  1337.000000  1337.000000       1337.000000
# mean      0.504862     0.795064     0.204936          0.242334
# std       0.500163     0.403806     0.403806          0.428655
# ...
