# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize'] = 6,2

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\hp\OneDrive\Pictures\Desktop\FSDS,Agentic AI\AUGUST\data.csv")
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
vis1 = sns.distplot(df['InternetUsers'])
plt.show()

# %%
sns.histplot(df['InternetUsers'], kde=True)
# Out:
# <Axes: xlabel='InternetUsers', ylabel='Count'>

# %%
sns.histplot(df['InternetUsers'], kde=True)
plt.show()

# %%
vis1 = sns.displot(df['InternetUsers'])
plt.show()

# %%
vis2 = sns.distplot(df['InternetUsers'],bins=10)
plt.show(vis2)

# %%
vis4 = sns.boxplot(data = df,x="IncomeGroup",y="BirthRate")
plt.show(vis4)

# %%
vis5 = sns.lmplot(data = df,x="InternetUsers",y="BirthRate")
plt.show(vis5)

# %%
vis5 = sns.lmplot(data = df,x="InternetUsers",y="BirthRate",fit_reg=False)
plt.show(vis5)

# %%
vis5 = sns.lmplot(data = df,x="InternetUsers",y="BirthRate",fit_reg=True)
plt.show(vis5)

# %%
vis6 = sns.lmplot(data = df,x="InternetUsers",y="BirthRate",   # hue parameter for colour.
                  fit_reg=False,hue= 'IncomeGroup')
plt.show(vis6)

# %%
vis9= sns.lmplot(data = df,x="InternetUsers",y="BirthRate",   # hue parameter for colour.
                  fit_reg=True,hue= 'IncomeGroup')
plt.show(vis9)
